# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11n.pt")

# %%
results = model.train(
    data=r"C:\Program Files (x86)\autonomous_car_project\for yolo\all_yolo.yaml", epochs=100,imgsz=512, batch=4, workers=2, patience=20, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.203 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.196  Python-3.11.13 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
model = YOLO(r"C:\Users\ASUS\Desktop\runs\detect\person\weights\best.pt")

# %%
model.val(data=r"C:\Program Files (x86)\autonomous_car_project\for yolo\all_yolo.yaml", imgsz=512, device=0)
# Out:
# Ultralytics 8.3.196  Python-3.11.13 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# val: Fast image access  (ping: 0.20.1 ms, read: 6.14.3 MB/s, size: 51.0 KB)
# val: Scanning C:\Program Files (x86)\autonomous_car_project\for yolo\Pothole_Detection.v16i.yolov11\valid\labels... 186 images, 28 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 186/186 507.5it/s 0.4s0.1s
# val: New cache created: C:\Program Files (x86)\autonomous_car_project\for yolo\Pothole_Detection.v16i.yolov11\valid\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 8.3it/s 1.4s0.2s
#                    all        186        653          0          0          0          0
#                pothole        158        653          0          0          0          0
# Speed: 0.2ms preprocess, 5.2ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to C:\Users\ASUS\Desktop\runs\detect\val2
# ...

# %%
results = model.train(data =r"C:\Program Files (x86)\autonomous_car_project\for yolo\all_yolo.yaml",  epochs=100,imgsz=512, batch=8, workers=2, patience=20, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.3.203 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.196  Python-3.11.13 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
model = YOLO(r"C:\Users\ASUS\Desktop\runs\detect\train21\weights\best.pt")

# %%
model.val(data= r"C:\Program Files (x86)\autonomous_car_project\for yolo\all_yolo.yaml", classes=[0], imgsz=512, device=0)
# Out:
# Ultralytics 8.3.196  Python-3.11.13 torch-2.8.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLO11n summary (fused): 100 layers, 2,584,102 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 777.3487.6 MB/s, size: 90.0 KB)
# val: Scanning C:\Program Files (x86)\autonomous_car_project\for yolo\Pothole_Detection.v16i.yolov11\valid\labels.cache... 186 images, 28 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 186/186  0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 8.4it/s 1.4s<0.2s
# c:\Users\ASUS\anaconda3\envs\ml_cv\Lib\site-packages\ultralytics\utils\metrics.py:668: RuntimeWarning: Mean of empty slice.
#   ax.plot(px, py.mean(1), linewidth=3, color="blue", label=f"all classes {ap[:, 0].mean():.3f} mAP@0.5")
# c:\Users\ASUS\anaconda3\envs\ml_cv\Lib\site-packages\numpy\_core\_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
# ...
